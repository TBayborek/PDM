# %%
# Import necessary libraries

import pandas as pd
import numpy as np
import math

import matplotlib.pyplot as plt
import matplotlib.transforms as transforms

from matplotlib.ticker import LinearLocator, FormatStrFormatter
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

from scipy import interpolate
import pickle

# %%
### Import data set
I_mes = [1,3,5] # Input current
Nsp = 98 # Number of spires
g1c_fem = 2.006E-4
KT_fem = 32.8E-3
#AJOUTER R0 mesuré pour KM

# To Read
C0 = ["C0_aller", "C0_retour"]
phase_single = ["U1","V1","W1","U2","V2","W2"]
phase_etoile = ["UVW1","VWU1","WUV1","UVW2","VWU2","WUV2","UVWT","VWUT","WUVT"]
phase = phase_single + phase_etoile

to_read = C0+phase

angle_step = 0.0141 # angular step
angle_vec = np.arange(0,360,angle_step)

Var_dict_mes = {} #Dictionnary containing mesured variables
for i, read_elem in enumerate(to_read):
    Couple_current = [] # Will contain for each phase, the torque for each current
    for j, I_mes_elem in enumerate(I_mes):
        
        if (read_elem in C0):
            if (j==0):
                df_raw = pd.read_csv("Mesures_couple/%s"%(read_elem), header = None,delimiter="\t")
            else: continue
        else:
            df_raw = pd.read_csv("Mesures_couple/%s_%iA"%(read_elem,I_mes_elem), header = None,delimiter="\t")
        
        df_raw.drop_duplicates(0,inplace=True)
        df_raw = np.array(df_raw.sort_values(by = 0))

        intp_couple = interpolate.interp1d(df_raw[:,0], df_raw[:,1], fill_value = "extrapolate")
        shift_angle = 1 # shift angle for the plot
        Couple_intp  = np.roll(intp_couple(angle_vec),int(shift_angle/angle_step))
        Couple_current.append(Couple_intp) # Store torque values
        
        if (read_elem in C0): # plot C0 later, just store value
            Var_dict_mes[read_elem] = Couple_intp # Add torque values to each phase variable
        else: # plot and store 
            plt.plot(angle_vec,Couple_intp*1000,label = "%iA"%I_mes_elem)
            Var_dict_mes[read_elem+"_mes"] = Couple_current # Add torque values to each phase variable
    
    
    if not (read_elem in C0):
        plt.xlabel("Angle mécanique [°]")
        plt.ylabel("Couple [mNm]")
        plt.xlim([0,360])
    
        plt.ylim([-150,150])
    
        plt.title("%s"%(read_elem+"_mes"))
        plt.legend(loc="lower right")
        plt.grid()
        plt.show()
    
locals().update(Var_dict_mes) # Create all variables in the dictionnary

# %%
# plot C0
for C0_elem in C0:
    plt.plot(angle_vec,eval(C0_elem)*1000,"-",label = C0_elem)
    
plt.xlabel("Angle mécanique [°]")
plt.ylabel("$C_0$ [mNm]")
plt.xlim([0,360])
plt.legend(loc="best")
plt.grid()
plt.savefig("C0_1i2.pdf")
plt.show()

C_frot = np.average(abs(eval(C0[1])-eval(C0[0])))/2


n_peak = 12
periode_elem = int(360/(n_peak*angle_step))
C_C0_aller_temp = []
C_C0_retour_temp = []
C_C0_temp = []
for i in range(0,n_peak):
    C_C0_aller_temp.append((max(eval(C0[0])[i*periode_elem:(i+1)*periode_elem])-min(eval(C0[0])[i*periode_elem:(i+1)*periode_elem]))/2)
    C_C0_retour_temp.append((max(eval(C0[1])[i*periode_elem:(i+1)*periode_elem])-min(eval(C0[1])[i*periode_elem:(i+1)*periode_elem]))/2)
    C_C0_temp.append(np.average([C_C0_aller_temp, C_C0_retour_temp])) 
    
C_C0_aller = max(C_C0_aller_temp)
C_C0_retour = max(C_C0_retour_temp)
C_C0 = max(C_C0_temp)

print("C_frot: \t%.3f[mNm]"%(C_frot*1000))

print("C0_aller: \t%.3f[mNm]"%(C_C0_aller*1000))
print("C0_retour: \t%.3f[mNm]"%(C_C0_retour*1000))
print("C0: \t\t%.3f[mNm]"%(C_C0*1000))


C0_df = pd.read_excel("C0_comparaison.xlsx",usecols = range(3),skiprows=1)
print(C0_df.head(3))

Angle = C0_df["Angle"]
C0_1i2 = C0_df["1i2"]

plt.plot(angle_vec,(C0_aller+C_frot)*1000,label="$C_0$ mesuré")
plt.plot(range(0,360),list(C0_1i2[:-1]*1000)*5,label="$C_0$ FEM")

plt.xlabel("Angle mécanique [°]")
plt.ylabel("$C_0$ [mNm]")
plt.ylim([-3.5,3.5])
plt.xlim([0,360])
plt.legend(loc="best")
plt.grid()
plt.savefig("C0_1i2_comparaison_FEM_MES.pdf")
plt.show()
# Out:
# C_frot: 	1.251[mNm]
# C0_aller: 	2.450[mNm]
# C0_retour: 	2.400[mNm]
# C0: 		2.425[mNm]
#    Angle       1i2    évidée
# 0      0  0.000029  0.000006
# 1      1 -0.000033  0.000014
# 2      2  0.000041  0.000115

# %%
#plot torques without C0
Var_dict = {} #Dictionnary containing adjusted variables (-C0)
for i, read_elem in enumerate(phase):
    torque_adjusted = []
    for j, I_mes_elem in enumerate(I_mes):
        torque_adjusted.append(eval(read_elem+"_mes")[j]-C0_aller)
        plt.plot(angle_vec,torque_adjusted[j]*1000,label = "%iA"%I_mes_elem)

        
    Var_dict[read_elem] = torque_adjusted
    plt.xlabel("Angle mécanique [°]")
    plt.ylabel("Couple [mNm]")
    plt.xlim([0,360])
    #plt.ylim([-150,150])
    plt.title("%s"%(read_elem))
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()
    
locals().update(Var_dict) # Create all variables in the dictionnary

# %%
# gamma 1 coil
Npp = 5
periode_elem = int(360/(Npp*angle_step))

plt.figure(figsize=(12,5))
colors = cm.rainbow(np.linspace(0, 1, Npp)) # Switch color for every peak, repeat for each phase

df_g1c = pd.DataFrame(columns = phase, index = ["average", "max", "min"])# Gamma1coil info
for i, read_elem in enumerate(phase):
    print(read_elem)
    zero_index = np.argmax(abs(eval(read_elem)[len(I_mes)-1])<1E-3) # Give an index where torque is approx 0
    gamma1coil_phase = []
    for j in range(0,Npp): # for each period
        gamma1coil_period = []
        for k, I_mes_elem in enumerate(I_mes):
            # start looking for the index for min and max torque on a period for a given current, period starting at approx C=0
            double_list = list(eval(read_elem)[2])*2 # double length of list so it can search on period ending after 360°
            max_torque_index  = zero_index+j*periode_elem+np.argmax(double_list[(zero_index+j*periode_elem):(zero_index+(j+1)*periode_elem)])
            min_torque_index  = zero_index+j*periode_elem+np.argmin(double_list[(zero_index+j*periode_elem):(zero_index+(j+1)*periode_elem)])

            max_torque_index = max_torque_index%(np.shape(eval(read_elem))[1]-1)
            min_torque_index = min_torque_index%(np.shape(eval(read_elem))[1]-1)

            gamma1coil_period.append((eval(read_elem)[k][max_torque_index]-eval(read_elem)[k][min_torque_index])/(2*Nsp*I_mes_elem))

        print("g1c_period : ",np.round(gamma1coil_period,6))    
        
        gamma1coil_phase.append(np.average(gamma1coil_period))
        
        # just add label for first phase, because they're all similar
        if (i==0): lab = "période "+str(j+1)
        else: lab = None

        w = 0.15
        plt.bar(i+(j-2)*w,gamma1coil_phase[j]*1000,width=w,color=colors[j],align='center',label = lab)    
        
    print("g1c_phase : ",np.round(gamma1coil_phase,6)) 
    df_g1c[read_elem] = [np.average(gamma1coil_phase), max(gamma1coil_phase), min(gamma1coil_phase)]

plt.xlabel("Phase")
plt.ylabel("$\gamma$ [E-3 Nm/Atrs]")
plt.xticks(range(0,len(phase)),phase)
plt.legend()
plt.grid()
plt.show()
# Out:
# U1
# g1c_period :  [0.000201 0.000199 0.000198]
# g1c_period :  [0.000208 0.000198 0.000199]
# g1c_period :  [0.000199 0.000198 0.000196]
# g1c_period :  [0.000196 0.000194 0.000193]
# g1c_period :  [0.000196 0.000192 0.000192]
# g1c_phase :  [0.000199 0.000202 0.000198 0.000194 0.000194]
# V1
# g1c_period :  [0.000206 0.000208 0.000217]
# g1c_period :  [0.000199 0.000203 0.000209]
# g1c_period :  [0.000197 0.0002   0.000207]
# g1c_period :  [0.000198 0.000202 0.000208]
# g1c_period :  [0.000202 0.000205 0.000213]
# g1c_phase :  [0.00021  0.000204 0.000201 0.000202 0.000207]
# W1
# g1c_period :  [0.000208 0.000204 0.000204]
# g1c_period :  [0.000204 0.0002   0.000198]
# g1c_period :  [0.000205 0.000198 0.000198]
# g1c_period :  [0.000203 0.000199 0.000198]
# g1c_period :  [0.000211 0.000207 0.000207]
# g1c_phase :  [0.000206 0.0002   0.0002   0.0002   0.000208]
# U2
# g1c_period :  [0.000204 0.000206 0.000213]
# g1c_period :  [0.000197 0.000202 0.00021 ]
# g1c_period :  [0.000201 0.000204 0.000213]
# g1c_period :  [0.00021  0.000211 0.000219]
# g1c_period :  [0.000211 0.000211 0.000219]
# g1c_phase :  [0.000208 0.000203 0.000206 0.000213 0.000214]
# V2
# g1c_period :  [0.000204 0.000199 0.000199]
# g1c_period :  [0.000206 0.000201 0.0002  ]
# g1c_period :  [0.000211 0.000207 0.000207]
# g1c_period :  [0.000207 0.000204 0.000203]
# g1c_period :  [0.0002   0.000199 0.000199]
# g1c_phase :  [0.0002   0.000203 0.000208 0.000205 0.0002  ]
# W2
# g1c_period :  [0.000195 0.000199 0.000208]
# g1c_period :  [0.000202 0.000206 0.000214]
# g1c_period :  [0.000206 0.00021  0.000218]
# g1c_period :  [0.000203 0.000204 0.000212]
# g1c_period :  [0.000197 0.000199 0.000207]
# g1c_phase :  [0.000201 0.000207 0.000211 0.000206 0.000201]
# UVW1
# g1c_period :  [0.000281 0.000275 0.000274]
# g1c_period :  [0.000285 0.00028  0.000279]
# g1c_period :  [0.000274 0.000274 0.000274]
# g1c_period :  [0.000273 0.000272 0.000273]
# g1c_period :  [0.000277 0.000271 0.000271]
# g1c_phase :  [0.000277 0.000281 0.000274 0.000272 0.000273]
# VWU1
# g1c_period :  [0.000284 0.000285 0.000291]
# g1c_period :  [0.000275 0.000272 0.000277]
# g1c_period :  [0.000276 0.000272 0.000275]
# g1c_period :  [0.000275 0.000273 0.000276]
# g1c_period :  [0.000281 0.000278 0.000284]
# g1c_phase :  [0.000286 0.000275 0.000274 0.000275 0.000281]
# WUV1
# g1c_period :  [0.000286 0.00028  0.000279]
# g1c_period :  [0.000282 0.000275 0.000276]
# g1c_period :  [0.000285 0.000276 0.000277]
# g1c_period :  [0.000282 0.000276 0.000276]
# g1c_period :  [0.00029  0.000284 0.000285]
# g1c_phase :  [0.000281 0.000278 0.000279 0.000278 0.000286]
# UVW2
# g1c_period :  [0.000275 0.000279 0.000284]
# g1c_period :  [0.000282 0.000278 0.000285]
# g1c_period :  [0.000271 0.000277 0.000284]
# g1c_period :  [0.000288 0.000288 0.000293]
# g1c_period :  [0.000285 0.000286 0.000291]
# g1c_phase :  [0.000279 0.000282 0.000277 0.00029  0.000287]
# VWU2
# g1c_period :  [0.000281 0.000274 0.000273]
# g1c_period :  [0.000275 0.000273 0.000273]
# g1c_period :  [0.000293 0.000287 0.000285]
# g1c_period :  [0.000289 0.000281 0.00028 ]
# g1c_period :  [0.000277 0.000271 0.000271]
# g1c_phase :  [0.000276 0.000274 0.000288 0.000283 0.000273]
# WUV2
# g1c_period :  [0.000275 0.000274 0.000282]
# g1c_period :  [0.000277 0.000278 0.000286]
# g1c_period :  [0.00029  0.000286 0.000293]
# g1c_period :  [0.00028  0.000278 0.000283]
# g1c_period :  [0.000278 0.000275 0.00028 ]
# g1c_phase :  [0.000277 0.000281 0.00029  0.00028  0.000278]
# UVWT
# g1c_period :  [0.000279 0.000273 0.000274]
# g1c_period :  [0.00028  0.000276 0.000276]
# g1c_period :  [0.000277 0.000271 0.000272]
# g1c_period :  [0.000283 0.000277 0.000277]
# g1c_period :  [0.000281 0.000275 0.000276]
# g1c_phase :  [0.000275 0.000277 0.000273 0.000279 0.000277]
# VWUT
# g1c_period :  [0.000282 0.000277 0.000277]
# g1c_period :  [0.00028  0.000273 0.000274]
# g1c_period :  [0.000283 0.000278 0.000278]
# g1c_period :  [0.00028  0.000275 0.000276]
# g1c_period :  [0.00028  0.000274 0.000274]
# g1c_phase :  [0.000279 0.000275 0.000279 0.000277 0.000276]
# WUVT
# g1c_period :  [0.000282 0.000275 0.000276]
# g1c_period :  [0.00028  0.000274 0.000275]
# g1c_period :  [0.000285 0.000279 0.000279]
# g1c_period :  [0.00028  0.000273 0.000274]
# g1c_period :  [0.000283 0.000277 0.000278]
# g1c_phase :  [0.000278 0.000276 0.000281 0.000275 0.000279]

# %%
print(df_g1c)

g1c_av = np.average(df_g1c.loc["average",phase_single])
g_star1_av = np.average(df_g1c.loc["average",phase_etoile[0:3]])
g_star2_av = np.average(df_g1c.loc["average",phase_etoile[3:7]])
g_star_av = np.average(df_g1c.loc["average",phase_etoile[-3:]])

KT = g_star_av*Nsp

fac_1c_m = 3/2
print("g1c_single_average\t: %.6f\terreur relative: %.1f%%"%(g1c_av, (g1c_av.round(6)-g1c_fem)/g1c_fem*100))
print("g_star1_average\t\t: %.6f\terreur relative: %.1f%%"%(g_star1_av, (g_star1_av.round(6)-fac_1c_m*g1c_fem)/(fac_1c_m*g1c_fem)*100))
print("g_star2_average\t\t: %.6f\terreur relative: %.1f%%"%(g_star2_av, (g_star2_av.round(6)-fac_1c_m*g1c_fem)/(fac_1c_m*g1c_fem)*100))
print("g_star_average\t\t: %.6f\terreur relative: %.1f%%"%(g_star_av, (g_star_av.round(6)-fac_1c_m*g1c_fem)/(fac_1c_m*g1c_fem)*100))

print("KT_double_etoile\t: %.5f\terreur relative: %.1f%%"%(KT, (KT-KT_fem)/KT_fem*100))
# Out:
#                U1        V1        W1        U2        V2        W2      UVW1  \
# average  0.000197  0.000205  0.000203  0.000209  0.000203  0.000205  0.000275
# max      0.000202  0.000210  0.000208  0.000214  0.000208  0.000211  0.000281
# min      0.000194  0.000201  0.000200  0.000203  0.000200  0.000201  0.000272
#
#              VWU1      WUV1      UVW2      VWU2      WUV2      UVWT      VWUT  \
# average  0.000278  0.000281  0.000283  0.000279  0.000281  0.000276  0.000277
# max      0.000286  0.000286  0.000290  0.000288  0.000290  0.000279  0.000279
# min      0.000274  0.000278  0.000277  0.000273  0.000277  0.000273  0.000275
#
#              WUVT
# average  0.000278
# max      0.000281
# min      0.000275
# g1c_single_average	: 0.000204	erreur relative: 1.7%
# g_star1_average		: 0.000278	erreur relative: -7.6%
# g_star2_average		: 0.000280	erreur relative: -6.9%
# g_star_average		: 0.000277	erreur relative: -7.9%
# KT_double_etoile	: 0.02716	erreur relative: -17.2%

# %%
# To Read
Current_max = ["10A", "20A"] #
Mes_num = range(1,6)

To_keep = ["10A_4", "20A_3"] # Seems like good curves
N_keep = []
T_keep = []

for i, curr_elem in enumerate(Current_max):
    for j, num_elem in enumerate(Mes_num):
        try:
            df_raw = pd.read_excel("Mesures_dynamique/Dyn_%s_%s.xlsx"%(curr_elem,str(num_elem)), sheet_name=1)
        except:
            continue

        df_raw = (df_raw.iloc[:,[0,2]]).sort_values(by = df_raw.columns[0], ascending = False)
        if sum(df_raw.iloc[1:,1].values-df_raw.iloc[:-1,1].values<0)==0:
            df = df_raw
        else:
            df = df_raw[:np.argmax(df_raw.iloc[1:,1].values-df_raw.iloc[:-1,1].values<0)+1]

        N = df.iloc[:,0]
        T = df.iloc[:,1]
        
        if curr_elem+"_"+str(num_elem) in To_keep:
            N_keep.append(N)
            T_keep.append(T)
            
        plt.plot(N,T*1000,"",label = "%s_%s"%(curr_elem,str(num_elem)))

        plt.xlabel("N [rpm]")
        plt.ylabel("Couple [mNm]")
        plt.xlim([0,6500])
        plt.ylim([0,600])

        plt.legend(loc="best")
        plt.grid(True)
plt.show()

# %%
df = pd.read_csv("Mesures_dynamique/Couple_10A", header = None,delimiter="\t")
df = df.sort_values(by = [0])
print(df.head())

angle = df.iloc[:,0]
T = df.iloc[:,1]
print("Couplemax :",max(T))

plt.plot(angle,T*1000)

plt.xlabel("Angle [°]")
plt.xlabel("Couple [mNm]")
plt.xlim([0,360])
#plt.ylim([-.3,.3])

plt.grid(True)
plt.show()
# Out:
#             0       1
# 25599  0.0000  0.0973
# 0      0.0141  0.0956
# 25600  0.0141  0.0973
# 1      0.0281  0.0956
# 25601  0.0281  0.0969
# Couplemax : 0.2852

# %%
max_T = [0.285,0.56] # max static torque for 10,20A
lab = ["10A","20A"]
T = []
N = []
for i,N_elem in enumerate(N_keep):
    max_index = (T_keep[i]>max_T[i]).idxmax()
    
    if max_index == 0 : max_index = len(T_keep[i])
    f = interpolate.interp1d(T_keep[i],N_keep[i], fill_value = "extrapolate")
    N_max_Torque = int(f(max_T[i]))
    
    T.append(list(T_keep[i][:max_index])+2*[max_T[i]])
    N.append(list(N_keep[i][:max_index])+[N_max_Torque,0])
    
    plt.plot(N[i],np.array(T[i])*1000, "o-",label = lab[i])

    plt.xlabel("N REFAIRE MESURE 20A STATIQUE [rpm]")
    plt.ylabel("Couple [mNm]")
    plt.xlim([0,6500])
    plt.ylim([0,600])
    
    plt.legend()
    plt.grid(True)
    plt.savefig("Couple_dyn_1i2_courant.pdf")
plt.show()

# %%
Temp = [-40, 20, 80 ,160]
# obj evidee, 1i2, evidee allongé

with open('TN_var.pkl',"rb") as f:  # Load variables of theoritical TN curves
    T_lim, N_lim = pickle.load(f)

for i in range(1,3):
    plt.plot(N_lim[i][1],np.array(T_lim[i][1])*1000, label = "T = %i°C (FEM)"%Temp[i])

plt.plot(N[1],np.array(T[1])*1000, "o-",label = "Mesuré")


plt.xlabel("N REFAIRE MESURE 20A STATIQUE [rpm]")
plt.ylabel("Couple [mNm]")
plt.legend()
plt.grid()
plt.savefig("Couple_dyn_mes_fem.pdf")
plt.show()

# %%
### Import data set
I_mes = 5 # Input current
Nsp = 98 # Number of spires
g1c_fem = 2.006E-4
KT_fem = 32.8E-3
#AJOUTER R0 mesuré pour KM

# To Read
phase_single = ["U1","V1","W1","U2","V2","W2"]
phase_etoile = ["UVW1","VWU1","WUV1","UVW2","VWU2","WUV2","UVWT","VWUT","WUVT"]
phase = phase_single + phase_etoile

to_read = phase

angle_step = 0.0141 # angular step
angle_vec = np.arange(0,360,angle_step)

Var_dict_mes = {} #Dictionnary containing mesured variables
for i, read_elem in enumerate(to_read):
        
    df_raw = pd.read_csv("Mesures_couple_demag/%s_5A"%(read_elem), header = None,delimiter="\t")
        
    df_raw.drop_duplicates(0,inplace=True)
    df_raw = np.array(df_raw.sort_values(by = 0))

    intp_couple = interpolate.interp1d(df_raw[:,0], df_raw[:,1], fill_value = "extrapolate")
    shift_angle = 1 # shift angle for the plot
    Couple_intp  = np.roll(intp_couple(angle_vec),int(shift_angle/angle_step))
    Couple_current = Couple_intp # Store torque values

    plt.plot(angle_vec,Couple_intp*1000,label = "5A")
    Var_dict_mes[read_elem] = Couple_current # Add torque values to each phase variable


    plt.xlabel("Angle mécanique [°]")
    plt.ylabel("Couple [mNm]")
    plt.xlim([0,360])

    plt.ylim([-150,150])

    plt.title("%s"%(read_elem+"_mes"))
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()
    
locals().update(Var_dict_mes) # Create all variables in the dictionnary

# %%
# gamma 1 coil
Npp = 5
periode_elem = int(360/(Npp*angle_step))

plt.figure(figsize=(12,5))
colors = cm.rainbow(np.linspace(0, 1, Npp)) # Switch color for every peak, repeat for each phase

df_g1c = pd.DataFrame(columns = phase, index = ["average", "max", "min"])# Gamma1coil info
for i, read_elem in enumerate(phase):
    print(read_elem)
    zero_index = np.argmax(abs(eval(read_elem))<1E-3) # Give an index where torque is approx 0
    gamma1coil_phase = []
    for j in range(0,Npp): # for each period
        gamma1coil_period = []

        # start looking for the index for min and max torque on a period for a given current, period starting at approx C=0
        double_list = list(eval(read_elem))*2 # double length of list so it can search on period ending after 360°
        max_torque_index  = zero_index+j*periode_elem+np.argmax(double_list[(zero_index+j*periode_elem):(zero_index+(j+1)*periode_elem)])
        min_torque_index  = zero_index+j*periode_elem+np.argmin(double_list[(zero_index+j*periode_elem):(zero_index+(j+1)*periode_elem)])

        max_torque_index = max_torque_index%(len(eval(read_elem))-1)
        min_torque_index = min_torque_index%(len(eval(read_elem))-1)

        gamma1coil_period.append((eval(read_elem)[max_torque_index]-eval(read_elem)[min_torque_index])/(2*Nsp*I_mes))

        print("g1c_period : ",np.round(gamma1coil_period,6))    
        
        gamma1coil_phase.append(np.average(gamma1coil_period))
        
        # just add label for first phase, because they're all similar
        if (i==0): lab = "période "+str(j+1)
        else: lab = None

        w = 0.15
        plt.bar(i+(j-2)*w,gamma1coil_phase[j]*1000,width=w,color=colors[j],align='center',label = lab)    
        
    print("g1c_phase : ",np.round(gamma1coil_phase,6)) 
    df_g1c[read_elem] = [np.average(gamma1coil_phase), max(gamma1coil_phase), min(gamma1coil_phase)]

plt.xlabel("Phase")
plt.ylabel("$\gamma$ [E-3 Nm/Atrs]")
plt.xticks(range(0,len(phase)),phase)
plt.legend()
plt.grid()
plt.show()
# Out:
# U1
# g1c_period :  [0.000188]
# g1c_period :  [0.000191]
# g1c_period :  [0.000198]
# g1c_period :  [0.000194]
# g1c_period :  [0.000196]
# g1c_phase :  [0.000188 0.000191 0.000198 0.000194 0.000196]
# V1
# g1c_period :  [0.000213]
# g1c_period :  [0.00021]
# g1c_period :  [0.000216]
# g1c_period :  [0.000217]
# g1c_period :  [0.000209]
# g1c_phase :  [0.000213 0.00021  0.000216 0.000217 0.000209]
# W1
# g1c_period :  [0.000207]
# g1c_period :  [0.00021]
# g1c_period :  [0.000199]
# g1c_period :  [0.000206]
# g1c_period :  [0.000201]
# g1c_phase :  [0.000207 0.00021  0.000199 0.000206 0.000201]
# U2
# g1c_period :  [0.000217]
# g1c_period :  [0.000217]
# g1c_period :  [0.000218]
# g1c_period :  [0.000217]
# g1c_period :  [0.000218]
# g1c_phase :  [0.000217 0.000217 0.000218 0.000217 0.000218]
# V2
# g1c_period :  [0.000201]
# g1c_period :  [0.000203]
# g1c_period :  [0.000196]
# g1c_period :  [0.000201]
# g1c_period :  [0.000205]
# g1c_phase :  [0.000201 0.000203 0.000196 0.000201 0.000205]
# W2
# g1c_period :  [0.00021]
# g1c_period :  [0.000209]
# g1c_period :  [0.000198]
# g1c_period :  [0.000209]
# g1c_period :  [0.000207]
# g1c_phase :  [0.00021  0.000209 0.000198 0.000209 0.000207]
# UVW1
# g1c_period :  [0.000268]
# g1c_period :  [0.000268]
# g1c_period :  [0.000278]
# g1c_period :  [0.000274]
# g1c_period :  [0.000271]
# g1c_phase :  [0.000268 0.000268 0.000278 0.000274 0.000271]
# VWU1
# g1c_period :  [0.000274]
# g1c_period :  [0.000283]
# g1c_period :  [0.00029]
# g1c_period :  [0.000286]
# g1c_period :  [0.000279]
# g1c_phase :  [0.000274 0.000283 0.00029  0.000286 0.000279]
# WUV1
# g1c_period :  [0.000282]
# g1c_period :  [0.000287]
# g1c_period :  [0.000277]
# g1c_period :  [0.000284]
# g1c_period :  [0.000282]
# g1c_phase :  [0.000282 0.000287 0.000277 0.000284 0.000282]
# UVW2
# g1c_period :  [0.000293]
# g1c_period :  [0.00029]
# g1c_period :  [0.000292]
# g1c_period :  [0.000289]
# g1c_period :  [0.00029]
# g1c_phase :  [0.000293 0.00029  0.000292 0.000289 0.00029 ]
# VWU2
# g1c_period :  [0.000276]
# g1c_period :  [0.000272]
# g1c_period :  [0.000276]
# g1c_period :  [0.000275]
# g1c_period :  [0.000282]
# g1c_phase :  [0.000276 0.000272 0.000276 0.000275 0.000282]
# WUV2
# g1c_period :  [0.00028]
# g1c_period :  [0.000285]
# g1c_period :  [0.000275]
# g1c_period :  [0.000282]
# g1c_period :  [0.000284]
# g1c_phase :  [0.00028  0.000285 0.000275 0.000282 0.000284]
# UVWT
# g1c_period :  [0.000277]
# g1c_period :  [0.000274]
# g1c_period :  [0.00028]
# g1c_period :  [0.000277]
# g1c_period :  [0.000275]
# g1c_phase :  [0.000277 0.000274 0.00028  0.000277 0.000275]
# VWUT
# g1c_period :  [0.000276]
# g1c_period :  [0.000274]
# g1c_period :  [0.000281]
# g1c_period :  [0.000278]
# g1c_period :  [0.00028]
# g1c_phase :  [0.000276 0.000274 0.000281 0.000278 0.00028 ]
# WUVT
# g1c_period :  [0.000274]
# g1c_period :  [0.000283]
# g1c_period :  [0.000269]
# g1c_period :  [0.000278]
# g1c_period :  [0.000276]
# g1c_phase :  [0.000274 0.000283 0.000269 0.000278 0.000276]

# %%
print(df_g1c)

g1c_av = np.average(df_g1c.loc["average",phase_single])
g_star1_av = np.average(df_g1c.loc["average",phase_etoile[0:3]])
g_star2_av = np.average(df_g1c.loc["average",phase_etoile[3:7]])
g_star_av = np.average(df_g1c.loc["average",phase_etoile[-3:]])

KT = g_star_av*Nsp

fac_1c_m = 3/2
print("g1c_single_average\t: %.6f\terreur relative: %.1f%%"%(g1c_av, (g1c_av.round(6)-g1c_fem)/g1c_fem*100))
print("g_star1_average\t\t: %.6f\terreur relative: %.1f%%"%(g_star1_av, (g_star1_av.round(6)-fac_1c_m*g1c_fem)/(fac_1c_m*g1c_fem)*100))
print("g_star2_average\t\t: %.6f\terreur relative: %.1f%%"%(g_star2_av, (g_star2_av.round(6)-fac_1c_m*g1c_fem)/(fac_1c_m*g1c_fem)*100))
print("g_star_average\t\t: %.6f\terreur relative: %.1f%%"%(g_star_av, (g_star_av.round(6)-fac_1c_m*g1c_fem)/(fac_1c_m*g1c_fem)*100))

print("KT_double_etoile\t: %.5f\terreur relative: %.1f%%"%(KT, (KT-KT_fem)/KT_fem*100))
# Out:
#                U1        V1        W1        U2        V2        W2      UVW1  \
# average  0.000193  0.000213  0.000205  0.000217  0.000201  0.000207  0.000272
# max      0.000198  0.000217  0.000210  0.000218  0.000205  0.000210  0.000278
# min      0.000188  0.000209  0.000199  0.000217  0.000196  0.000198  0.000268
#
#              VWU1      WUV1      UVW2      VWU2      WUV2      UVWT      VWUT  \
# average  0.000282  0.000282  0.000291  0.000276  0.000281  0.000277  0.000278
# max      0.000290  0.000287  0.000293  0.000282  0.000285  0.000280  0.000281
# min      0.000274  0.000277  0.000289  0.000272  0.000275  0.000274  0.000274
#
#              WUVT
# average  0.000276
# max      0.000283
# min      0.000269
# g1c_single_average	: 0.000206	erreur relative: 2.7%
# g_star1_average		: 0.000279	erreur relative: -7.3%
# g_star2_average		: 0.000281	erreur relative: -6.6%
# g_star_average		: 0.000277	erreur relative: -7.9%
# KT_double_etoile	: 0.02712	erreur relative: -17.3%
